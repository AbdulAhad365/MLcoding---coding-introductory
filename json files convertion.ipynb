# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Sample data
corpus = [
    'This is the first document.',
    'This document is the second document.',
    'And this is the third one s.',
    'Is this the first document ?',
]

# Initialize the TfidfVectorizer
vectorizer = TfidfVectorizer()

# Fit and transform the corpus
X = vectorizer.fit_transform(corpus)

print(X.toarray())
print(vectorizer.get_feature_names_out())
# Out:
# [[0.         0.46979139 0.58028582 0.38408524 0.         0.
#   0.38408524 0.         0.38408524]
#  [0.         0.6876236  0.         0.28108867 0.         0.53864762
#   0.28108867 0.         0.28108867]
#  [0.51184851 0.         0.         0.26710379 0.51184851 0.
#   0.26710379 0.51184851 0.26710379]
#  [0.         0.46979139 0.58028582 0.38408524 0.         0.
#   0.38408524 0.         0.38408524]]
# ['and' 'document' 'first' 'is' 'one' 'second' 'the' 'third' 'this']

# %%
from gensim.models import Word2Vec

# Sample data
sentences = [
    ['this', 'is', 'the', 'first', 'document'],
    ['this', 'document', 'is', 'the', 'second', 'document'],
    ['and', 'this', 'is', 'the', 'third', 'one'],
    ['is', 'this', 'the', 'first', 'document']
]

# Initialize the Word2Vec model
model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)

# Train the model
model.train(sentences, total_examples=len(sentences), epochs=100)

# Get vector for a word
print(model.wv['the'])
# Out:
# [-0.00870223  0.00372817  0.00522117  0.00576825  0.0074742  -0.00620182
#   0.00121883  0.00612509 -0.00292751 -0.00626837 -0.00034922 -0.00840448
#  -0.00560951  0.00711158  0.00338634  0.00718928  0.00689334  0.00756231
#  -0.00390094 -0.00064594  0.00233342 -0.00452923  0.0085953  -0.00985013
#   0.00673895  0.00293595 -0.00492059  0.00436784 -0.00176822  0.00675391
#   0.01007469 -0.00441128 -0.00064006 -0.00576131  0.00382882  0.0028922
#   0.00694939  0.00608649  0.00952418  0.00925868  0.0080157  -0.0070486
#  -0.00917897 -0.00041138 -0.00304128  0.00796485  0.00590606 -0.00156128
#   0.00148593  0.00176795  0.00785201 -0.00963334 -0.00025679  0.00345832
#  -0.00106111  0.00836403  0.00908099  0.00650124 -0.00076522  0.0076396
#  -0.00852293  0.00318758 -0.00451556 -0.00514619  0.00358585  0.00544245
#   0.00775374 -0.00571036  0.00732865  0.00655274 -0.00370101 -0.00870021
#   0.00550346  0.00663761 -0.00078753 -0.00675159 -0.00713139 -0.00244437
# ...

# %%
# model.most_similar('document')
model['document']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # model.most_similar('document')
# ----> 2 model['document']
#
# TypeError: 'Word2Vec' object is not subscriptable

# %%
import numpy as np

# Get all words in the vocabulary
words = model.wv.index_to_key

# Create an empty similarity matrix
similarity_matrix = np.zeros((len(words), len(words)))

# Compute cosine similarity between all word vectors
for i, word1 in enumerate(words):
    for j, word2 in enumerate(words):
        similarity_matrix[i][j] = model.wv.similarity(word1, word2)

# Print words used in comparison
print("Words:", words)

# Print similarity matrix
print("Similarity Matrix:\n", similarity_matrix)
# Out:
# Words: ['document', 'the', 'is', 'this', 'first', 'one', 'third', 'and', 'second']
# Similarity Matrix:
#  [[ 1.         -0.00341676 -0.03997204 -0.10109372 -0.02542775 -0.05069494
#    0.02424364  0.09672813  0.03304081]
#  [-0.00341676  1.         -0.01669158  0.07650959  0.0057529   0.01792324
#   -0.10318816 -0.1108029   0.04048228]
#  [-0.03997204 -0.01669158  1.         -0.00400032  0.17068209  0.07236873
#    0.15436295  0.00261657  0.2041591 ]
#  [-0.10109372  0.07650959 -0.00400032  1.         -0.0427839   0.14026228
#    0.04952662 -0.00845933  0.08446165]
#  [-0.02542775  0.0057529   0.17068209 -0.0427839   1.          0.13947508
#    0.03587789 -0.02702585 -0.06778997]
#  [-0.05069494  0.01792324  0.07236873  0.14026228  0.13947508  1.
#    0.02836691 -0.05150887  0.06800029]
#  [ 0.02424364 -0.10318816  0.15436295  0.04952662  0.03587789  0.02836691
#    1.          0.01015933  0.01561676]
#  [ 0.09672813 -0.1108029   0.00261657 -0.00845933 -0.02702585 -0.05150887
# ...

# %%
similarity_matrix.shape
# Out:
# (9, 9)

# %%
arr=np.zeros((len(words),len(words)))
# arr=np.zeros((len(words), len(words)))

# one word similarity to the other word

# %%
# GLOVEE MODEL TO USE



import gensim.downloader as api

# Download pre-trained GloVe model (choose the size you need - 50, 100, 200, or 300 dimensions)
glove_vectors = api.load("glove-wiki-gigaword-100")  # Example: 100-dimensional GloVe

# Get word vectors (embeddings)
word1 = "king"
word2 = "queen"
vector1 = glove_vectors[word1]
vector2 = glove_vectors[word2]

# Compute cosine similarity between the two word vectors
similarity = glove_vectors.similarity(word1, word2)

print(f"Word vectors for '{word1}': {vector1}")
print(f"Word vectors for '{word2}': {vector2}")
print(f"Cosine similarity between '{word1}' and '{word2}': {similarity}")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded
# Word vectors for 'king': [-0.32307  -0.87616   0.21977   0.25268   0.22976   0.7388   -0.37954
#  -0.35307  -0.84369  -1.1113   -0.30266   0.33178  -0.25113   0.30448
#  -0.077491 -0.89815   0.092496 -1.1407   -0.58324   0.66869  -0.23122
#  -0.95855   0.28262  -0.078848  0.75315   0.26584   0.3422   -0.33949
#   0.95608   0.065641  0.45747   0.39835   0.57965   0.39267  -0.21851
#   0.58795  -0.55999   0.63368  -0.043983 -0.68731  -0.37841   0.38026
#   0.61641  -0.88269  -0.12346  -0.37928  -0.38318   0.23868   0.6685
#  -0.43321  -0.11065   0.081723  1.1569    0.78958  -0.21223  -2.3211
#  -0.67806   0.44561   0.65707   0.1045    0.46217   0.19912   0.25802
#   0.057194  0.53443  -0.43133  -0.34311   0.59789  -0.58417   0.068995
#   0.23944  -0.85181   0.30379  -0.34177  -0.25746  -0.031101 -0.16285
#   0.45169  -0.91627   0.64521   0.73281  -0.22752   0.30226   0.044801
# ...

# %%
import requests

url = "https://imdb236.p.rapidapi.com/imdb/tt7631058/cast"

headers = {
	"x-rapidapi-key": "cd9290a385msh4f9db86b55e4623p1b118ajsnb0f2c4f569c8",
	"x-rapidapi-host": "imdb236.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# [{'id': 'nm6077056', 'url': 'https://www.imdb.com/name/nm6077056/', 'fullName': 'Morfydd Clark', 'job': 'actress', 'characters': ['Galadriel']}, {'id': 'nm8190914', 'url': 'https://www.imdb.com/name/nm8190914/', 'fullName': 'Charlie Vickers', 'job': 'actor', 'characters': ['Sauron', 'Halbrand']}, {'id': 'nm0249876', 'url': 'https://www.imdb.com/name/nm0249876/', 'fullName': 'Charles Edwards', 'job': 'actor', 'characters': ['Lord Celebrimbor']}, {'id': 'nm3033454', 'url': 'https://www.imdb.com/name/nm3033454/', 'fullName': 'Ismael Cruz Cordova', 'job': 'actor', 'characters': ['Arondir']}, {'id': 'nm7075019', 'url': 'https://www.imdb.com/name/nm7075019/', 'fullName': 'Robert Aramayo', 'job': 'actor', 'characters': ['Elrond']}, {'id': 'nm6003807', 'url': 'https://www.imdb.com/name/nm6003807/', 'fullName': 'Robert Strange', 'job': 'actor', 'characters': ['Glûg', 'Barrow-Wight', 'Dying Orc']}, {'id': 'nm9220161', 'url': 'https://www.imdb.com/name/nm9220161/', 'fullName': 'Markella Kavenag
# ...

# %%
response
# Out:
# <Response [200]>

# %%
p=json.loads(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 p=json.loads(response)
#
# File C:\ProgramData\anaconda3\Lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not Response

# %%
import requests  # Import the requests library to make an HTTP request

# Define the API endpoint URL
url = "https://imdb236.p.rapidapi.com/imdb/tt7631058/cast"

# Define the headers required for the API request
headers = {
    "x-rapidapi-key": "cd9290a385msh4f9db86b55e4623p1b118ajsnb0f2c4f569c8",  # Your API key (keep it secure)
    "x-rapidapi-host": "imdb236.p.rapidapi.com"  # The API host
}

# Make the GET request to the API with the provided URL and headers
response = requests.get(url, headers=headers)

# Convert the response to JSON format and print it
# Ensure the request was successful before accessing JSON data
if response.status_code == 200:  # Check if the request was successful (HTTP 200 OK)
    print(response.json())  # Parse and print the JSON response
else:
    print(f"Error: {response.status_code}, {response.text}")  # Print error details if request fails
# Out:
# [{'id': 'nm6077056', 'url': 'https://www.imdb.com/name/nm6077056/', 'fullName': 'Morfydd Clark', 'job': 'actress', 'characters': ['Galadriel']}, {'id': 'nm8190914', 'url': 'https://www.imdb.com/name/nm8190914/', 'fullName': 'Charlie Vickers', 'job': 'actor', 'characters': ['Sauron', 'Halbrand']}, {'id': 'nm0249876', 'url': 'https://www.imdb.com/name/nm0249876/', 'fullName': 'Charles Edwards', 'job': 'actor', 'characters': ['Lord Celebrimbor']}, {'id': 'nm3033454', 'url': 'https://www.imdb.com/name/nm3033454/', 'fullName': 'Ismael Cruz Cordova', 'job': 'actor', 'characters': ['Arondir']}, {'id': 'nm7075019', 'url': 'https://www.imdb.com/name/nm7075019/', 'fullName': 'Robert Aramayo', 'job': 'actor', 'characters': ['Elrond']}, {'id': 'nm6003807', 'url': 'https://www.imdb.com/name/nm6003807/', 'fullName': 'Robert Strange', 'job': 'actor', 'characters': ['Glûg', 'Barrow-Wight', 'Dying Orc']}, {'id': 'nm9220161', 'url': 'https://www.imdb.com/name/nm9220161/', 'fullName': 'Markella Kavenag
# ...

# %%
import pandas as pd
p = response.json()

# Convert to Pandas DataFrame
df = pd.DataFrame(p)

# %%
df
# Out:
#             id                                    url                fullName  \
# 0    nm6077056   https://www.imdb.com/name/nm6077056/           Morfydd Clark
# 1    nm8190914   https://www.imdb.com/name/nm8190914/         Charlie Vickers
# 2    nm0249876   https://www.imdb.com/name/nm0249876/         Charles Edwards
# 3    nm3033454   https://www.imdb.com/name/nm3033454/     Ismael Cruz Cordova
# 4    nm7075019   https://www.imdb.com/name/nm7075019/          Robert Aramayo
# 5    nm6003807   https://www.imdb.com/name/nm6003807/          Robert Strange
# 6    nm9220161   https://www.imdb.com/name/nm9220161/       Markella Kavenagh
# 7    nm1621849   https://www.imdb.com/name/nm1621849/           Daniel Weyman
# 8   nm10090380  https://www.imdb.com/name/nm10090380/          Megan Richards
# 9    nm1870963   https://www.imdb.com/name/nm1870963/  Cynthia Addai-Robinson
# 10   nm4259881   https://www.imdb.com/name/nm4259881/           Patrick McKay
# ...

# %% [raw]
# import requests
#
# url = "https://books-recommendation-270k-books.p.rapidapi.com/list"
#
# payload = {
# 	"page": "1",
# 	"year": "2000"
# }
# headers = {
# 	"x-rapidapi-key": "cd9290a385msh4f9db86b55e4623p1b118ajsnb0f2c4f569c8",
# 	"x-rapidapi-host": "books-recommendation-270k-books.p.rapidapi.com",
# 	"Content-Type": "application/x-www-form-urlencoded"
# }
#
# response = requests.post(url, data=payload, headers=headers)
#
# print(response.json())

# %%
import pandas as pd
p = response.json()

# Convert to Pandas DataFrame
df = pd.DataFrame(p)

# %%
df
# Out:
#                                                          result
# current_page                                                  1
# data          [{'ISBN': '0425176428', 'BookTitle': 'What If?...
# from                                                          1
# to                                                           50
# per_page                                                     50
# total                                                     17239

# %%
import pandas as pd
wow=df['result'].iloc[1]
wow
# Out:
# [{'ISBN': '0425176428',
#   'BookTitle': "What If?: The World's Foremost Military Historians Imagine What Might Have Been",
#   'BookAuthor': 'Robert Cowley',
#   'YearOfPublication': '2000',
#   'Publisher': 'Berkley Publishing Group',
#   'ImageURLS': 'http://images.amazon.com/images/P/0425176428.01.THUMBZZZ.jpg',
#   'ImageURLM': 'http://images.amazon.com/images/P/0425176428.01.MZZZZZZZ.jpg',
#   'ImageURLL': 'http://images.amazon.com/images/P/0425176428.01.LZZZZZZZ.jpg'},
#  {'ISBN': '080652121X',
#   'BookTitle': "Hitler's Secret Bankers: The Myth of Swiss Neutrality During the Holocaust",
#   'BookAuthor': 'Adam Lebor',
#   'YearOfPublication': '2000',
#   'Publisher': 'Citadel Press',
#   'ImageURLS': 'http://images.amazon.com/images/P/080652121X.01.THUMBZZZ.jpg',
#   'ImageURLM': 'http://images.amazon.com/images/P/080652121X.01.MZZZZZZZ.jpg',
#   'ImageURLL': 'http://images.amazon.com/images/P/080652121X.01.LZZZZZZZ.jpg'},
#  {'ISBN': '0061076031',
# ...

# %%
pd.DataFrame(wow)
# Out:
#           ISBN                                          BookTitle  \
# 0   0425176428  What If?: The World's Foremost Military Histor...
# 1   080652121X  Hitler's Secret Bankers: The Myth of Swiss Neu...
# 2   0061076031  Mary-Kate &amp; Ashley Switching Goals (Mary-K...
# 3   0345417623                                           Timeline
# 4   3442446937                                 Tage der Unschuld.
# 5   0375406328                                        Lying Awake
# 6   0553582909                                           Icebound
# 7   0842342702  Left Behind: A Novel of the Earth's Last Days ...
# 8   0312970242                                  The Angel Is Near
# 9   0375410538                                       Anil's Ghost
# 10  0340767936                                     Turning Thirty
# 11  0446677450  Rich Dad, Poor Dad: What the Rich Teach Their ...
# 12  0446608653                                          The Alibi
# ...
